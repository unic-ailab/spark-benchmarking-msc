# %% [markdown]
# <h2>Python Code</h2>

# %%
import pandas as pd
import time

# Load the CSV file into a pandas DataFrame
df_1 = pd.read_csv("Data/Reddit_2021_2022/outputRS_2021-01.csv")
df_2 = pd.read_csv("Data/Reddit_2021_2022/outputRS_2021-02.csv")
df_3 = pd.read_csv("Data/Reddit_2021_2022/outputRS_2021-03.csv")
df_4 = pd.read_csv("Data/Reddit_2021_2022/outputRS_2021-04.csv")
df_5 = pd.read_csv("Data/Reddit_2021_2022/outputRS_2021-05.csv")
df_6 = pd.read_csv("Data/Reddit_2021_2022/outputRS_2021-06.csv")
df_7 = pd.read_csv("Data/Reddit_2021_2022/outputRS_2021-07.csv")
df_8 = pd.read_csv("Data/Reddit_2021_2022/outputRS_2021-08.csv")
df_9 = pd.read_csv("Data/Reddit_2021_2022/outputRS_2021-09.csv")
df_10 = pd.read_csv("Data/Reddit_2021_2022/outputRS_2021-10.csv")
df_11 = pd.read_csv("Data/Reddit_2021_2022/outputRS_2021-11.csv")
df_12 = pd.read_csv("Data/Reddit_2021_2022/outputRS_2021-12.csv")
# Concatenate the two DataFrames
combined_df = pd.concat([df_1, df_2, df_3, df_4, df_5, df_6], ignore_index=True)
                        
# # Execute the query (Example: Selecting top 10 rows)
# query_result = df.head(10)

# # Print the result
# print(query_result)

# %%
# Start timing
start_time = time.time()

# Perform groupby, count in Pandas
result_df = df_1.groupby("subreddit").size().reset_index(name="count")

# Sort the DataFrame by the count column
result_df = result_df.sort_values(by="count", ascending=False)

# Calculate the time difference
load_time = time.time() - start_time
print("Time difference in seconds: {:.2f}".format(load_time))

# %%
# Start timing
start_time = time.time()

# Perform groupby, count in Pandas
result_df = df_2.groupby("subreddit").size().reset_index(name="count")

# Sort the DataFrame by the count column
result_df = result_df.sort_values(by="count", ascending=False)

# Calculate the time difference
load_time = time.time() - start_time
print("Time difference in seconds: {:.2f}".format(load_time))

# %%
# Start timing
start_time = time.time()

# Perform groupby, count in Pandas
result_df = combined_df.groupby("subreddit").size().reset_index(name="count")

# Sort the DataFrame by the count column
result_df = result_df.sort_values(by="count", ascending=False)

# Calculate the time difference
load_time = time.time() - start_time
print("Time difference in seconds: {:.2f}".format(load_time))

# %% [markdown]
# <h2>Spark Code</h2>

# %%
import pyspark
from pyspark import SparkContext, SparkConf
from pyspark.sql import SparkSession, SQLContext, functions as F
from pyspark.sql.functions import *
from pyspark.ml.stat import Correlation
from pyspark.ml.feature import VectorAssembler, StopWordsRemover, HashingTF, IDF
from pyspark.ml import Pipeline
import findspark
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import string
import time

findspark.init()

# Create a SparkSession
spark = SparkSession.builder \
    .appName("Thesis") \
    .getOrCreate()

# # Configure Spark properties
# conf = SparkConf()
# conf.set("spark.executor.cores", "4")  # Number of CPU cores per executor
# conf.set("spark.executor.memory", "8g")  # Memory allocated to each executor

# # Create SparkSession with the configured properties
# spark = SparkSession.builder \
#     .appName("Thesis") \
#     .config(conf=conf) \
#     .getOrCreate()

# %%
# Load CSV data into a DataFrames
df_2021_01 = spark.read.csv("Data/Reddit_2021_2022/outputRS_2021-01.csv", header=True, inferSchema=True)
df_2021_02 = spark.read.csv("Data/Reddit_2021_2022/outputRS_2021-02.csv", header=True, inferSchema=True)
df_2021_03 = spark.read.csv("Data/Reddit_2021_2022/outputRS_2021-03.csv", header=True, inferSchema=True)
df_2021_04 = spark.read.csv("Data/Reddit_2021_2022/outputRS_2021-04.csv", header=True, inferSchema=True)
df_2021_05 = spark.read.csv("Data/Reddit_2021_2022/outputRS_2021-05.csv", header=True, inferSchema=True)
df_2021_06 = spark.read.csv("Data/Reddit_2021_2022/outputRS_2021-06.csv", header=True, inferSchema=True)
df_2021_07 = spark.read.csv("Data/Reddit_2021_2022/outputRS_2021-07.csv", header=True, inferSchema=True)
df_2021_08 = spark.read.csv("Data/Reddit_2021_2022/outputRS_2021-08.csv", header=True, inferSchema=True)
df_2021_09 = spark.read.csv("Data/Reddit_2021_2022/outputRS_2021-09.csv", header=True, inferSchema=True)
df_2021_10 = spark.read.csv("Data/Reddit_2021_2022/outputRS_2021-10.csv", header=True, inferSchema=True)
df_2021_11 = spark.read.csv("Data/Reddit_2021_2022/outputRS_2021-11.csv", header=True, inferSchema=True)
df_2021_12 = spark.read.csv("Data/Reddit_2021_2022/outputRS_2021-12.csv", header=True, inferSchema=True)

df_2022_01 = spark.read.csv("Data/Reddit_2021_2022/outputRS_2022-01.csv", header=True, inferSchema=True)
df_2022_02 = spark.read.csv("Data/Reddit_2021_2022/outputRS_2022-02.csv", header=True, inferSchema=True)
df_2022_03 = spark.read.csv("Data/Reddit_2021_2022/outputRS_2022-03.csv", header=True, inferSchema=True)
df_2022_04 = spark.read.csv("Data/Reddit_2021_2022/outputRS_2022-04.csv", header=True, inferSchema=True)
df_2022_05 = spark.read.csv("Data/Reddit_2021_2022/outputRS_2022-05.csv", header=True, inferSchema=True)
df_2022_06 = spark.read.csv("Data/Reddit_2021_2022/outputRS_2022-06.csv", header=True, inferSchema=True)
df_2022_07 = spark.read.csv("Data/Reddit_2021_2022/outputRS_2022-07.csv", header=True, inferSchema=True)
df_2022_08 = spark.read.csv("Data/Reddit_2021_2022/outputRS_2022-08.csv", header=True, inferSchema=True)
df_2022_09 = spark.read.csv("Data/Reddit_2021_2022/outputRS_2022-09.csv", header=True, inferSchema=True)
df_2022_10 = spark.read.csv("Data/Reddit_2021_2022/outputRS_2022-10.csv", header=True, inferSchema=True)
df_2022_11 = spark.read.csv("Data/Reddit_2021_2022/outputRS_2022-11.csv", header=True, inferSchema=True)
df_2022_12 = spark.read.csv("Data/Reddit_2021_2022/outputRS_2022-12.csv", header=True, inferSchema=True)

# %%
# Union the DataFrames together to create a single DataFrame
merged_df_2021_01_02 = df_2021_01.union(df_2021_02)
merged_df_2021_Q1 = merged_df_2021_01_02.union(df_2021_03)
merged_df_2021_04_05 = df_2021_04.union(df_2021_05)
merged_df_2021_Q2 = merged_df_2021_04_05.union(df_2021_06)
merged_df_half_2021 = merged_df_2021_Q1.union(merged_df_2021_Q2)

merged_df_2021_07_08 = df_2021_07.union(df_2021_08)
merged_df_2021_Q3 = merged_df_2021_07_08.union(df_2021_09)
merged_df_2021_10_11 = df_2021_10.union(df_2021_11)
merged_df_2021_Q4 = merged_df_2021_10_11.union(df_2021_12)
merged_df_2021 = merged_df_half_2021.union(merged_df_2021_Q3).union(merged_df_2021_Q4)

# %%
# Union the DataFrames together to create a single DataFrame
merged_df_2022_01_02 = df_2022_01.union(df_2022_02)
merged_df_2022_Q1 = merged_df_2022_01_02.union(df_2022_03)
merged_df_2022_04_05 = df_2022_04.union(df_2022_05)
merged_df_2022_Q2 = merged_df_2022_04_05.union(df_2022_06)
merged_df_half_2022 = merged_df_2022_Q1.union(merged_df_2022_Q2)

merged_df_2022_07_08 = df_2022_07.union(df_2022_08)
merged_df_2022_Q3 = merged_df_2022_07_08.union(df_2022_09)
merged_df_2022_10_11 = df_2022_10.union(df_2022_11)
merged_df_2022_Q4 = merged_df_2022_10_11.union(df_2022_12)
merged_df_2022 = merged_df_half_2022.union(merged_df_2022_Q3).union(merged_df_2022_Q4)

# %%
merged_df_all = merged_df_2021.union(merged_df_2022)

# %%
# Define English stopwords
stopwords = StopWordsRemover().getStopWords()

# %%
df_2021_01.show()

# %% [markdown]
# <b>Queries for testing</b>

# %%
# Start timing
start_time = time.time()

result_df = df_2021_01.groupBy("subreddit").count().orderBy(col("count").desc())
# Show the result
result_df.show()

# Calculate the time difference
load_time = time.time() - start_time
print("Time difference in seconds: {:.2f}".format(load_time))

# %%
# Calculate the number of separate groups
num_groups = result_df.count()

print("Number of separate groups:", num_groups)

# %%
# Start timing
start_time = time.time()

result_df = df_2021_01.groupBy("title").count().orderBy(col("count").desc())
# Show the result
result_df.show()

# Calculate the time difference
load_time = time.time() - start_time
print("Time difference in seconds: {:.2f}".format(load_time))

# %%
# Calculate the number of separate groups
num_groups = result_df.count()

print("Number of separate groups:", num_groups)

# %%
# Start timing
start_time = time.time()

df_2021_01 \
    .select(lower(col("title")).alias("title")) \
    .withColumn("words", split(col("title"), "\\s+")) \
    .select(explode("words").alias("word")) \
    .groupBy("word") \
    .count() \
    .show()

# Calculate the time difference
load_time = time.time() - start_time
print("Time difference in seconds: {:.2f}".format(load_time))

# %%
# Start timing
start_time = time.time()

# Remove punctuation and English stopwords, and perform word count
result_df = df_2021_01.select(lower(col("title")).alias("title")) \
                       .withColumn("title_no_punctuation", regexp_replace(col("title"), "[^a-zA-Z\\s]", "")) \
                       .withColumn("words", split(col("title_no_punctuation"), "\\s+")) \
                       .select(explode("words").alias("word")) \
                       .filter(~col("word").isin(stopwords)) \
                       .groupBy("word") \
                       .count() \
                       .orderBy(col("count").desc()) 

# Show the result
result_df.show()

# Calculate the time difference
load_time = time.time() - start_time
print("Time difference in seconds: {:.2f}".format(load_time))

# %%
# Start timing
start_time = time.time()

# Remove punctuation, symbols, and English stopwords, and perform word count
result_df = df_2021_01.select(lower(col("self_text")).alias("self_text")) \
                       .withColumn("self_text_no_punctuation", regexp_replace(col("self_text"), "[^a-zA-Z\\s]", "")) \
                       .withColumn("words", split(col("self_text_no_punctuation"), "\\s+")) \
                       .select(explode("words").alias("word")) \
                       .filter(~col("word").isin(stopwords)) \
                       .groupBy("word") \
                       .count() \
                       .orderBy(col("count").desc())

# Show the result
result_df.show()

# Calculate the time difference
load_time = time.time() - start_time
print("Time difference in seconds: {:.2f}".format(load_time))

# %%
from pyspark.ml.feature import StopWordsRemover, Tokenizer

# Start timing
start_time = time.time()

# Tokenize the text and calculate term frequency (TF)
tokenizer = Tokenizer(inputCol="title", outputCol="words")
# hashingTF = HashingTF(inputCol="words", outputCol="rawFeatures", numFeatures=10000)
hashingTF = HashingTF(inputCol="words", outputCol="rawFeatures")

# Compute IDF
idf = IDF(inputCol="rawFeatures", outputCol="features")

# Create a pipeline
pipeline = Pipeline(stages=[tokenizer, hashingTF, idf])

# Fit the pipeline to the data
pipeline_model = pipeline.fit(df_2021_01)

# Transform the data to calculate TF-IDF
tfidf_result = pipeline_model.transform(df_2021_01)

# Show the result
tfidf_result.select("words", "features").show()

# Calculate the time difference
load_time = time.time() - start_time
print("Time difference in seconds: {:.2f}".format(load_time))

# %% [markdown]
# <h3>Actual Testing</h3>

# %% [markdown]
# <b>First Query</b>

# %%
# Start timing
start_time = time.time()

df_2021_01.groupBy("subreddit").count().orderBy(col("count").desc()).show()

# Calculate the time difference
load_time = time.time() - start_time
print("Time difference in seconds: {:.2f}".format(load_time))
# Out:
# +------------------+------+
# |         subreddit| count|
# +------------------+------+
# |    wallstreetbets|535460|
# |         AskReddit|378771|
# |             memes|291530|
# |    u_toronto_news|271238|
# |         teenagers|141341|
# |     InspirobotBot|129496|
# |      dirtykikpals|119271|
# |       GaySnapchat|110303|
# |          dogecoin|106332|
# |     AutoNewspaper|103936|
# |       FreeKarma4U| 92933|
# |OnlyFansPromotions| 90162|
# |  PokemonGoFriends| 90067|
# |  onlyfansgirls101| 88059|
# |             false| 85734|
# |         dankmemes| 84469|
# |      DiscordNudes| 83045|
# |          gonewild| 81661|
# |               ksi| 81534|
# |      dirtypenpals| 80099|
# +------------------+------+
# only showing top 20 rows
#
# Time difference in seconds: 19.51

# %%
# Start timing
start_time = time.time()

merged_df_2021_Q1.groupBy("subreddit").count().orderBy(col("count").desc()).show()

# Calculate the time difference
load_time = time.time() - start_time
print("Time difference in seconds: {:.2f}".format(load_time))
# Out:
# +------------------+-------+
# |         subreddit|  count|
# +------------------+-------+
# |    wallstreetbets|1057413|
# |         AskReddit|1052730|
# |    u_toronto_news| 787568|
# |             memes| 758011|
# |     InspirobotBot| 676881|
# |         teenagers| 444626|
# |          dogecoin| 355912|
# |      dirtykikpals| 347563|
# |       GaySnapchat| 340011|
# |     AutoNewspaper| 317730|
# |  PokemonGoFriends| 306945|
# |  onlyfansgirls101| 292381|
# |         manywords| 274950|
# |OnlyFansPromotions| 264414|
# |       FreeKarma4U| 249562|
# |      dirtypenpals| 229311|
# |     DirtySnapchat| 226718|
# |          gonewild| 226135|
# |       OnlyFans101| 219242|
# |      DiscordNudes| 217832|
# +------------------+-------+
# only showing top 20 rows
#
# Time difference in seconds: 50.06

# %%
# Start timing
start_time = time.time()

merged_df_half_2021.groupBy("subreddit").count().orderBy(col("count").desc()).show()

# Calculate the time difference
load_time = time.time() - start_time
print("Time difference in seconds: {:.2f}".format(load_time))
# Out:
# +------------------+-------+
# |         subreddit|  count|
# +------------------+-------+
# |       FreeKarma4U|2449642|
# |         AskReddit|2048292|
# |             memes|1379707|
# |    u_toronto_news|1248797|
# |    wallstreetbets|1246567|
# |          dogecoin| 869047|
# |         teenagers| 821817|
# |     InspirobotBot| 803080|
# |      dirtykikpals| 796629|
# |       GaySnapchat| 772897|
# |  onlyfansgirls101| 665303|
# |     AutoNewspaper| 599378|
# |      SnapchatSext| 530172|
# |OnlyFansPromotions| 515843|
# |     DirtySnapchat| 454077|
# |               196| 446225|
# |      dirtypenpals| 445597|
# |          gonewild| 430548|
# |  PokemonGoFriends| 429644|
# |             false| 418475|
# +------------------+-------+
# only showing top 20 rows
#
# Time difference in seconds: 108.27

# %%
# Start timing
start_time = time.time()

merged_df_2021.groupBy("subreddit").count().orderBy(col("count").desc()).show()

# Calculate the time difference
load_time = time.time() - start_time
print("Time difference in seconds: {:.2f}".format(load_time))
# Out:
# +------------------+-------+
# |         subreddit|  count|
# +------------------+-------+
# |         AskReddit|4003387|
# |       FreeKarma4U|3885660|
# |             memes|2158606|
# |      dirtykikpals|1827863|
# |       GaySnapchat|1724387|
# |         teenagers|1559643|
# |    wallstreetbets|1404534|
# |  onlyfansgirls101|1300779|
# |    u_toronto_news|1248797|
# |     AutoNewspaper|1104221|
# |OnlyFansPromotions| 982883|
# |          dogecoin| 980987|
# |     DirtySnapchat| 933685|
# |          dirtyr4r| 891766|
# |      dirtypenpals| 837694|
# |          gonewild| 817053|
# |     InspirobotBot| 803555|
# |  PokemonGoFriends| 771692|
# |               196| 760354|
# |     NSFW_Tributes| 749733|
# +------------------+-------+
# only showing top 20 rows
#
# Time difference in seconds: 192.68

# %%
# Start timing
start_time = time.time()

merged_df_all.groupBy("subreddit").count().orderBy(col("count").desc()).show()

# Calculate the time difference
load_time = time.time() - start_time
print("Time difference in seconds: {:.2f}".format(load_time))
# Out:
# +-------------------+-------+
# |          subreddit|  count|
# +-------------------+-------+
# |          AskReddit|7652886|
# |        FreeKarma4U|4686427|
# |       dirtykikpals|4027127|
# |        GaySnapchat|3868827|
# |           dirtyr4r|3077621|
# |              memes|2978257|
# |          teenagers|2852321|
# |          jerkbudss|2478281|
# |      DirtySnapchat|2100374|
# |   onlyfansgirls101|2048485|
# |      AutoNewspaper|2026411|
# |     u_toronto_news|1918873|
# |     wallstreetbets|1648309|
# |           gonewild|1607887|
# |relationship_advice|1591126|
# |        MassiveCock|1573105|
# |       dirtypenpals|1556535|
# | OnlyFansPromotions|1545355|
# |      NSFW_Tributes|1513542|
# |               cock|1460450|
# +-------------------+-------+
# only showing top 20 rows
#
# Time difference in seconds: 402.35

# %% [markdown]
# <b>Second Query</b>

# %%
# Start timing
start_time = time.time()

df_2021_01.groupBy("title").count().orderBy(col("count").desc()).show()

# Calculate the time difference
load_time = time.time() - start_time
print("Time difference in seconds: {:.2f}".format(load_time))
# Out:
# +--------------------+-----+
# |               title|count|
# +--------------------+-----+
# |     GET CHEAP KARMA|55399|
# |  Praise Todd Howard|32173|
# |                   .|29231|
# |                Rule|26457|
# |AIs from AI Dunge...|15049|
# |                 wow| 9739|
# |                rule| 9438|
# |This is the newes...| 8218|
# |                Help| 7886|
# |             Amazing| 7863|
# |I just posted thi...| 7579|
# |      You like this?| 7520|
# |                hmmm| 7470|
# |                Test| 7429|
# |                 ...| 7334|
# |              me_irl| 7256|
# | You like this view?| 7201|
# |21 [F4R] sexy stu...| 6801|
# |            Hot view| 6601|
# |                  Hi| 6572|
# +--------------------+-----+
# only showing top 20 rows
#
# Time difference in seconds: 40.03

# %%
# Start timing
start_time = time.time()

merged_df_2021_Q1.groupBy("title").count().orderBy(col("count").desc()).show()

# Calculate the time difference
load_time = time.time() - start_time
print("Time difference in seconds: {:.2f}".format(load_time))
# Out:
# +--------------------+-----+
# |               title|count|
# +--------------------+-----+
# |  Praise Todd Howard|94127|
# |                   .|84930|
# |                Rule|83409|
# |Free OnlyFans and...|81651|
# |                  hi|79000|
# |     I got ya homie!|65664|
# |     GET CHEAP KARMA|55403|
# |AIs from AI Dunge...|54042|
# |OnlyLeaks - Free ...|42064|
# |22 [F4M] Hi daddy...|34421|
# |                rule|30299|
# |This is the newes...|25443|
# |                 ...|24692|
# |                Help|22749|
# |                hmmm|22504|
# |    Link in comments|21445|
# |              me_irl|20326|
# |                  Hi|20144|
# |                Test|19661|
# |                 wow|17610|
# +--------------------+-----+
# only showing top 20 rows
#
# Time difference in seconds: 107.05

# %%
# Start timing
start_time = time.time()

merged_df_half_2021.groupBy("title").count().orderBy(col("count").desc()).show()

# Calculate the time difference
load_time = time.time() - start_time
print("Time difference in seconds: {:.2f}".format(load_time))
# Out:
# +--------------------+------+
# |               title| count|
# +--------------------+------+
# |                   .|188641|
# |  Praise Todd Howard|188033|
# |💫 $SAFEPLUTO 💫 ...|170178|
# |🐺 Polo Finance S...|168048|
# |                Rule|166607|
# |AIs from AI Dunge...|100799|
# |                  hi| 87164|
# |Free OnlyFans and...| 81651|
# |Upvote For Upvote...| 74877|
# |     I got ya homie!| 65664|
# |                rule| 63151|
# |     GET CHEAP KARMA| 55403|
# |                  Sh| 54627|
# |                   1| 53909|
# |This is the newes...| 51478|
# |                hmmm| 45673|
# |                Help| 44922|
# |22 [F4M] Hi daddy...| 44078|
# |                 ...| 44077|
# |   Doping for Google| 43683|
# +--------------------+------+
# only showing top 20 rows
#
# Time difference in seconds: 219.57

# %%
# Start timing
start_time = time.time()

merged_df_2021.groupBy("title").count().orderBy(col("count").desc()).show()

# Calculate the time difference
load_time = time.time() - start_time
print("Time difference in seconds: {:.2f}".format(load_time))
# Out:
# +--------------------+--------+
# |               title|   count|
# +--------------------+--------+
# |   [deleted by user]|24458108|
# |  Praise Todd Howard|  352692|
# |                   .|  336066|
# |Upvote For Upvote...|  272010|
# |                Rule|  260323|
# |💫 $SAFEPLUTO 💫 ...|  170178|
# |🐺 Polo Finance S...|  168048|
# |       💗☁🍦🌸🧁🤍🦩|  139379|
# |                rule|  102069|
# |AIs from AI Dunge...|  100807|
# |                  hi|   98379|
# |Free OnlyFans and...|   81651|
# |                hmmm|   81510|
# |                Help|   79742|
# |                  Hi|   78706|
# |                Test|   69346|
# |     I got ya homie!|   65665|
# |                 ...|   63579|
# |                   1|   62383|
# |            Question|   62237|
# +--------------------+--------+
# only showing top 20 rows
#
# Time difference in seconds: 410.82

# %%
# Start timing
start_time = time.time()

merged_df_all.groupBy("title").count().orderBy(col("count").desc()).show()

# Calculate the time difference
load_time = time.time() - start_time
print("Time difference in seconds: {:.2f}".format(load_time))
# Out:
# +--------------------+--------+
# |               title|   count|
# +--------------------+--------+
# |   [deleted by user]|33376246|
# |                   .|  723769|
# |  Praise Todd Howard|  548410|
# |                Rule|  346165|
# |         Dale Wilson|  282969|
# |Upvote For Upvote...|  272012|
# |[ Removed by Redd...|  215359|
# |                rule|  181410|
# |💫 $SAFEPLUTO 💫 ...|  170178|
# |🐺 Polo Finance S...|  168048|
# |Ethereum Name Ser...|  167133|
# |   New Members Intro|  166211|
# |                  Hi|  162025|
# |                IRTR|  158395|
# |Saferbot performe...|  153403|
# |                hmmm|  147906|
# |                  hi|  145098|
# |                Help|  143275|
# |                Test|  141245|
# |       💗☁🍦🌸🧁🤍🦩|  139379|
# +--------------------+--------+
# only showing top 20 rows
#
# Time difference in seconds: 883.64

# %% [markdown]
# <b>Third Query</b>

# %%
# Start timing
start_time = time.time()

df_2021_01 \
    .select(lower(col("title")).alias("title")) \
    .withColumn("words", split(col("title"), "\\s+")) \
    .select(explode("words").alias("word")) \
    .groupBy("word") \
    .count() \
    .show()

# Calculate the time difference
load_time = time.time() - start_time
print("Time difference in seconds: {:.2f}".format(load_time))
# Out:
# +---------+------+
# |     word| count|
# +---------+------+
# |     some|671204|
# | ""invite|  1089|
# |    still|225734|
# |  reddit,| 34076|
# |      few| 94411|
# |   online|145139|
# |     hope|179880|
# |      art|132690|
# |    oscar|  2265|
# |    delas|    32|
# |    innnn|    31|
# |    those| 92664|
# |    spoil| 10857|
# |  embrace|  2935|
# | inverted|  1789|
# |abspritze|     2|
# |      ...| 72676|
# |    poppy|  1343|
# |    ruiz.|     9|
# |   outfit| 21214|
# +---------+------+
# only showing top 20 rows
#
# Time difference in seconds: 72.02

# %%
# Start timing
start_time = time.time()

merged_df_2021_Q1 \
    .select(lower(col("title")).alias("title")) \
    .withColumn("words", split(col("title"), "\\s+")) \
    .select(explode("words").alias("word")) \
    .groupBy("word") \
    .count() \
    .show()

# Calculate the time difference
load_time = time.time() - start_time
print("Time difference in seconds: {:.2f}".format(load_time))
# Out:
# +---------+-------+
# |     word|  count|
# +---------+-------+
# |     some|2005278|
# | ""invite|   1115|
# |    still| 655999|
# |  reddit,|  96513|
# |      few| 279277|
# |   online| 444059|
# |     hope| 546070|
# |      art| 292829|
# |    oscar|   8640|
# |    delas|    106|
# |    innnn|     65|
# |    those| 270438|
# |    spoil|  34603|
# |  embrace|   9332|
# | inverted|   5368|
# |abspritze|      9|
# |      ...| 214833|
# |    poppy|   4083|
# |    ruiz.|     28|
# |   outfit|  61104|
# +---------+-------+
# only showing top 20 rows
#
# Time difference in seconds: 201.03

# %%
# Start timing
start_time = time.time()

merged_df_half_2021 \
    .select(lower(col("title")).alias("title")) \
    .withColumn("words", split(col("title"), "\\s+")) \
    .select(explode("words").alias("word")) \
    .groupBy("word") \
    .count() \
    .show()

# Calculate the time difference
load_time = time.time() - start_time
print("Time difference in seconds: {:.2f}".format(load_time))
# Out:
# +---------+-------+
# |     word|  count|
# +---------+-------+
# |     some|4088013|
# | ""invite|   1149|
# |    still|1359426|
# |  reddit,| 185784|
# |      few| 579699|
# |   online| 890268|
# |     hope|1154242|
# |      art| 574438|
# |    oscar|  18028|
# |    delas|    234|
# |    innnn|    111|
# |    those| 548926|
# |    spoil|  66094|
# |  embrace|  20947|
# | inverted|   9352|
# |abspritze|     29|
# |      ...| 432356|
# |    poppy|   8380|
# |    ruiz.|     56|
# |   outfit| 130329|
# +---------+-------+
# only showing top 20 rows
#
# Time difference in seconds: 410.18

# %%
# Start timing
start_time = time.time()

merged_df_2021 \
    .select(lower(col("title")).alias("title")) \
    .withColumn("words", split(col("title"), "\\s+")) \
    .select(explode("words").alias("word")) \
    .groupBy("word") \
    .count() \
    .show()

# Calculate the time difference
load_time = time.time() - start_time
print("Time difference in seconds: {:.2f}".format(load_time))
# Out:
# +---------+-------+
# |     word|  count|
# +---------+-------+
# |     some|6900761|
# | ""invite|   1201|
# |    still|2368334|
# |  reddit,| 294914|
# |      few|1032929|
# |   online|1534647|
# |     hope|1923908|
# |      art| 988222|
# |    oscar|  28190|
# |    delas|    405|
# |    innnn|    162|
# |    those| 938450|
# |    spoil| 107019|
# |  embrace|  34909|
# | inverted|  14702|
# |abspritze|     60|
# |      ...| 686931|
# |    poppy|  16191|
# |    ruiz.|     96|
# |   outfit| 231641|
# +---------+-------+
# only showing top 20 rows
#
# Time difference in seconds: 734.79

# %%
# Start timing
start_time = time.time()

merged_df_all \
    .select(lower(col("title")).alias("title")) \
    .withColumn("words", split(col("title"), "\\s+")) \
    .select(explode("words").alias("word")) \
    .groupBy("word") \
    .count() \
    .show()

# Calculate the time difference
load_time = time.time() - start_time
print("Time difference in seconds: {:.2f}".format(load_time))
# Out:
# +---------+--------+
# |     word|   count|
# +---------+--------+
# |     some|15176577|
# | ""invite|    1329|
# |    still| 4858012|
# |  reddit,|  578433|
# |      few| 2084720|
# |   online| 3241299|
# |     hope| 4370914|
# |      art| 1873532|
# |    oscar|   62006|
# |    delas|    3029|
# |    innnn|     322|
# |    those| 1886178|
# |    spoil|  303257|
# |  embrace|   69343|
# | inverted|   28135|
# |abspritze|     925|
# |      ...| 1283664|
# |    poppy|   35598|
# |    ruiz.|     709|
# |   outfit|  544591|
# +---------+--------+
# only showing top 20 rows
#
# Time difference in seconds: 1561.57

# %% [markdown]
# <b>Fourth Query</b>

# %%
# Start timing
start_time = time.time()

# Remove punctuation, symbols, and English stopwords, and perform word count
df_2021_01.select(lower(col("self_text")).alias("self_text")) \
                       .withColumn("self_text_no_punctuation", regexp_replace(col("self_text"), "[^a-zA-Z\\s]", "")) \
                       .withColumn("words", split(col("self_text_no_punctuation"), "\\s+")) \
                       .select(explode("words").alias("word")) \
                       .filter(~col("word").isin(stopwords)) \
                       .groupBy("word") \
                       .count() \
                       .orderBy(col("count").desc()) \
                       .show()

# Calculate the time difference
load_time = time.time() - start_time
print("Time difference in seconds: {:.2f}".format(load_time))
# Out:
# +-------+-------+
# |   word|  count|
# +-------+-------+
# |deleted|7287934|
# |removed|2968247|
# |     im|2583357|
# |   like|1931836|
# |    get|1390687|
# |    one|1256082|
# |   know|1219049|
# |   dont|1202669|
# |   time|1065486|
# |    ive| 997148|
# |   want| 978956|
# |   also| 904908|
# | really| 828441|
# |    new| 746761|
# |looking| 728724|
# | people| 707541|
# |   even| 706216|
# |     xb| 664189|
# |  think| 653736|
# | anyone| 651245|
# +-------+-------+
# only showing top 20 rows
#
# Time difference in seconds: 112.66

# %%
# Start timing
start_time = time.time()

# Remove punctuation, symbols, and English stopwords, and perform word count
merged_df_2021_Q1.select(lower(col("self_text")).alias("self_text")) \
                       .withColumn("self_text_no_punctuation", regexp_replace(col("self_text"), "[^a-zA-Z\\s]", "")) \
                       .withColumn("words", split(col("self_text_no_punctuation"), "\\s+")) \
                       .select(explode("words").alias("word")) \
                       .filter(~col("word").isin(stopwords)) \
                       .groupBy("word") \
                       .count() \
                       .orderBy(col("count").desc()) \
                       .show()

# Calculate the time difference
load_time = time.time() - start_time
print("Time difference in seconds: {:.2f}".format(load_time))
# Out:
# +-------+--------+
# |   word|   count|
# +-------+--------+
# |deleted|20720163|
# |removed| 8497464|
# |     im| 7728772|
# |   like| 5861089|
# |    get| 4250855|
# |    one| 3785393|
# |   know| 3728515|
# |   dont| 3642788|
# |   time| 3226916|
# |    ive| 3020090|
# |   want| 2937648|
# |   also| 2755210|
# | really| 2465725|
# | people| 2252361|
# |    new| 2225525|
# |looking| 2204506|
# |   even| 2151537|
# |     xb| 2108329|
# |       | 2003218|
# |  think| 2002546|
# +-------+--------+
# only showing top 20 rows
#
# Time difference in seconds: 331.45

# %%
# Start timing
start_time = time.time()

# Remove punctuation, symbols, and English stopwords, and perform word count
merged_df_half_2021.select(lower(col("self_text")).alias("self_text")) \
                       .withColumn("self_text_no_punctuation", regexp_replace(col("self_text"), "[^a-zA-Z\\s]", "")) \
                       .withColumn("words", split(col("self_text_no_punctuation"), "\\s+")) \
                       .select(explode("words").alias("word")) \
                       .filter(~col("word").isin(stopwords)) \
                       .groupBy("word") \
                       .count() \
                       .orderBy(col("count").desc()) \
                       .show()

# Calculate the time difference
load_time = time.time() - start_time
print("Time difference in seconds: {:.2f}".format(load_time))
# Out:
# +-------+--------+
# |   word|   count|
# +-------+--------+
# |deleted|38860881|
# |removed|17722515|
# |     im|16137120|
# |   like|12104664|
# |    get| 8911611|
# |    one| 7835127|
# |   dont| 7691165|
# |   know| 7565790|
# |   time| 6787255|
# |   want| 6159136|
# |    ive| 6090416|
# |   also| 5741874|
# |     xb| 5230372|
# | really| 5055914|
# |    new| 4793542|
# | people| 4578141|
# |   even| 4440467|
# |looking| 4324172|
# |   make| 4222497|
# |   back| 4113665|
# +-------+--------+
# only showing top 20 rows
#
# Time difference in seconds: 687.10

# %%
# Start timing
start_time = time.time()

# Remove punctuation, symbols, and English stopwords, and perform word count
merged_df_2021.select(lower(col("self_text")).alias("self_text")) \
                       .withColumn("self_text_no_punctuation", regexp_replace(col("self_text"), "[^a-zA-Z\\s]", "")) \
                       .withColumn("words", split(col("self_text_no_punctuation"), "\\s+")) \
                       .select(explode("words").alias("word")) \
                       .filter(~col("word").isin(stopwords)) \
                       .groupBy("word") \
                       .count() \
                       .orderBy(col("count").desc()) \
                       .show()

# Calculate the time difference
load_time = time.time() - start_time
print("Time difference in seconds: {:.2f}".format(load_time))
# Out:
# +-------+--------+
# |   word|   count|
# +-------+--------+
# |deleted|58568104|
# |removed|56411887|
# |     im|29301060|
# |   like|22351280|
# |    get|16482152|
# |    one|14564876|
# |   dont|14046279|
# |   know|13812872|
# |   time|12798581|
# |   want|11306339|
# |    ive|11083354|
# |     xb|11023442|
# |   also|10766352|
# | really| 9263807|
# |    new| 8987961|
# | people| 8389778|
# |   even| 8265552|
# |   make| 7798109|
# |    cum| 7769988|
# |looking| 7700677|
# +-------+--------+
# only showing top 20 rows
#
# Time difference in seconds: 1278.63

# %%
# Start timing
start_time = time.time()

# Remove punctuation, symbols, and English stopwords, and perform word count
merged_df_all.select(lower(col("self_text")).alias("self_text")) \
                       .withColumn("self_text_no_punctuation", regexp_replace(col("self_text"), "[^a-zA-Z\\s]", "")) \
                       .withColumn("words", split(col("self_text_no_punctuation"), "\\s+")) \
                       .select(explode("words").alias("word")) \
                       .filter(~col("word").isin(stopwords)) \
                       .groupBy("word") \
                       .count() \
                       .orderBy(col("count").desc()) \
                       .show()

# Calculate the time difference
load_time = time.time() - start_time
print("Time difference in seconds: {:.2f}".format(load_time))
# Out:
# +-------+---------+
# |   word|    count|
# +-------+---------+
# |deleted|130410040|
# |removed|106943625|
# |     im| 61511822|
# |   like| 46658615|
# |    get| 34954692|
# |    one| 30626010|
# |   dont| 29050120|
# |   know| 28418472|
# |   time| 26589501|
# |   want| 23652180|
# |    ive| 22956827|
# |   also| 22080894|
# |     xb| 21575920|
# | really| 18957845|
# |    new| 18470683|
# |   even| 17489898|
# | people| 17058757|
# |       | 16191584|
# |looking| 15894693|
# |   back| 15798017|
# +-------+---------+
# only showing top 20 rows
#
# Time difference in seconds: 2688.67

# %% [markdown]
# <b>Fifth Query</b>

# %%
# Start timing
start_time = time.time()

# Remove punctuation, symbols, and English stopwords, and perform word count
df_2021_01.select(lower(col("self_text")).alias("self_text")) \
                       .withColumn("self_text_no_punctuation", regexp_replace(col("self_text"), "[^a-zA-Z\\s]", "")) \
                       .withColumn("words", split(col("self_text_no_punctuation"), "\\s+")) \
                       .select(explode("words").alias("word")) \
                       .filter(~col("word").isin(stopwords)) \
                       .groupBy("word") \
                       .count() \
                       .orderBy(col("count").desc()) \
                       .show()

# Calculate the time difference
load_time = time.time() - start_time
print("Time difference in seconds: {:.2f}".format(load_time))
# Out:
# +-------+-------+
# |   word|  count|
# +-------+-------+
# |deleted|7287934|
# |removed|2968247|
# |     im|2583357|
# |   like|1931836|
# |    get|1390687|
# |    one|1256082|
# |   know|1219049|
# |   dont|1202669|
# |   time|1065486|
# |    ive| 997148|
# |   want| 978956|
# |   also| 904908|
# | really| 828441|
# |    new| 746761|
# |looking| 728724|
# | people| 707541|
# |   even| 706216|
# |     xb| 664189|
# |  think| 653736|
# | anyone| 651245|
# +-------+-------+
# only showing top 20 rows
#
# Time difference in seconds: 112.97

# %%
# Start timing
start_time = time.time()

# Remove punctuation, symbols, and English stopwords, and perform word count
merged_df_2021_Q1.select(lower(col("self_text")).alias("self_text")) \
                       .withColumn("self_text_no_punctuation", regexp_replace(col("self_text"), "[^a-zA-Z\\s]", "")) \
                       .withColumn("words", split(col("self_text_no_punctuation"), "\\s+")) \
                       .select(explode("words").alias("word")) \
                       .filter(~col("word").isin(stopwords)) \
                       .groupBy("word") \
                       .count() \
                       .orderBy(col("count").desc()) \
                       .show()

# Calculate the time difference
load_time = time.time() - start_time
print("Time difference in seconds: {:.2f}".format(load_time))
# Out:
# +-------+--------+
# |   word|   count|
# +-------+--------+
# |deleted|20720163|
# |removed| 8497464|
# |     im| 7728772|
# |   like| 5861089|
# |    get| 4250855|
# |    one| 3785393|
# |   know| 3728515|
# |   dont| 3642788|
# |   time| 3226916|
# |    ive| 3020090|
# |   want| 2937648|
# |   also| 2755210|
# | really| 2465725|
# | people| 2252361|
# |    new| 2225525|
# |looking| 2204506|
# |   even| 2151537|
# |     xb| 2108329|
# |       | 2003218|
# |  think| 2002546|
# +-------+--------+
# only showing top 20 rows
#
# Time difference in seconds: 330.91

# %%
# Start timing
start_time = time.time()

# Remove punctuation, symbols, and English stopwords, and perform word count
merged_df_half_2021.select(lower(col("self_text")).alias("self_text")) \
                       .withColumn("self_text_no_punctuation", regexp_replace(col("self_text"), "[^a-zA-Z\\s]", "")) \
                       .withColumn("words", split(col("self_text_no_punctuation"), "\\s+")) \
                       .select(explode("words").alias("word")) \
                       .filter(~col("word").isin(stopwords)) \
                       .groupBy("word") \
                       .count() \
                       .orderBy(col("count").desc()) \
                       .show()

# Calculate the time difference
load_time = time.time() - start_time
print("Time difference in seconds: {:.2f}".format(load_time))
# Out:
# +-------+--------+
# |   word|   count|
# +-------+--------+
# |deleted|38860881|
# |removed|17722515|
# |     im|16137120|
# |   like|12104664|
# |    get| 8911611|
# |    one| 7835127|
# |   dont| 7691165|
# |   know| 7565790|
# |   time| 6787255|
# |   want| 6159136|
# |    ive| 6090416|
# |   also| 5741874|
# |     xb| 5230372|
# | really| 5055914|
# |    new| 4793542|
# | people| 4578141|
# |   even| 4440467|
# |looking| 4324172|
# |   make| 4222497|
# |   back| 4113665|
# +-------+--------+
# only showing top 20 rows
#
# Time difference in seconds: 685.25

# %%
# Start timing
start_time = time.time()

# Remove punctuation, symbols, and English stopwords, and perform word count
merged_df_2021.select(lower(col("self_text")).alias("self_text")) \
                       .withColumn("self_text_no_punctuation", regexp_replace(col("self_text"), "[^a-zA-Z\\s]", "")) \
                       .withColumn("words", split(col("self_text_no_punctuation"), "\\s+")) \
                       .select(explode("words").alias("word")) \
                       .filter(~col("word").isin(stopwords)) \
                       .groupBy("word") \
                       .count() \
                       .orderBy(col("count").desc()) \
                       .show()

# Calculate the time difference
load_time = time.time() - start_time
print("Time difference in seconds: {:.2f}".format(load_time))
# Out:
# +-------+--------+
# |   word|   count|
# +-------+--------+
# |deleted|58568104|
# |removed|56411887|
# |     im|29301060|
# |   like|22351280|
# |    get|16482152|
# |    one|14564876|
# |   dont|14046279|
# |   know|13812872|
# |   time|12798581|
# |   want|11306339|
# |    ive|11083354|
# |     xb|11023442|
# |   also|10766352|
# | really| 9263807|
# |    new| 8987961|
# | people| 8389778|
# |   even| 8265552|
# |   make| 7798109|
# |    cum| 7769988|
# |looking| 7700677|
# +-------+--------+
# only showing top 20 rows
#
# Time difference in seconds: 1278.10

# %%
# Start timing
start_time = time.time()

# Remove punctuation, symbols, and English stopwords, and perform word count
merged_df_all.select(lower(col("self_text")).alias("self_text")) \
                       .withColumn("self_text_no_punctuation", regexp_replace(col("self_text"), "[^a-zA-Z\\s]", "")) \
                       .withColumn("words", split(col("self_text_no_punctuation"), "\\s+")) \
                       .select(explode("words").alias("word")) \
                       .filter(~col("word").isin(stopwords)) \
                       .groupBy("word") \
                       .count() \
                       .orderBy(col("count").desc()) \
                       .show()

# Calculate the time difference
load_time = time.time() - start_time
print("Time difference in seconds: {:.2f}".format(load_time))
# Out:
# +-------+---------+
# |   word|    count|
# +-------+---------+
# |deleted|130410040|
# |removed|106943625|
# |     im| 61511822|
# |   like| 46658615|
# |    get| 34954692|
# |    one| 30626010|
# |   dont| 29050120|
# |   know| 28418472|
# |   time| 26589501|
# |   want| 23652180|
# |    ive| 22956827|
# |   also| 22080894|
# |     xb| 21575920|
# | really| 18957845|
# |    new| 18470683|
# |   even| 17489898|
# | people| 17058757|
# |       | 16191584|
# |looking| 15894693|
# |   back| 15798017|
# +-------+---------+
# only showing top 20 rows
#
# Time difference in seconds: 2689.98

# %%
# Stop SparkSession
spark.stop()

# %% [markdown]
# <b>Other Tests</b>

# %%
start_time = time.time()
word_freq_df = df_2021_01 \
    .select(lower(col("self_text")).alias("self_text")) \
    .withColumn("words", split(col("self_text"), "\\s+")) \
    .select(explode("words").alias("word")) \
    .filter(~col("word").isin(["the", "and", "is"])) \
    .groupBy("word") \
    .count()

# Compute the average frequency of each word
average_word_freq_df = word_freq_df \
    .groupBy("word") \
    .agg({"count": "avg"}) \
    .withColumnRenamed("avg(count)", "average_frequency")

# Show the result
average_word_freq_df.show()

load_time = time.time() - start_time
print("Time difference in seconds: {:.2f}".format(load_time))

# %%
start_time = time.time()
word_freq_df = merged_df_2021_Q1 \
    .select(lower(col("self_text")).alias("self_text")) \
    .withColumn("words", split(col("self_text"), "\\s+")) \
    .select(explode("words").alias("word")) \
    .filter(~col("word").isin(["the", "and", "is"])) \
    .groupBy("word") \
    .count()

# Compute the average frequency of each word
average_word_freq_df = word_freq_df \
    .groupBy("word") \
    .agg({"count": "avg"}) \
    .withColumnRenamed("avg(count)", "average_frequency")

# Show the result
average_word_freq_df.show()

load_time = time.time() - start_time
print("Time difference in seconds: {:.2f}".format(load_time))

# %%
from pyspark.ml.feature import Tokenizer, StopWordsRemover, CountVectorizer
from pyspark.ml.clustering import KMeans
from pyspark.ml import Pipeline

# Load the dataset into a Spark DataFrame (assuming 'data' is your DataFrame)
# Preprocessing: Tokenization, Remove stopwords, Convert text to numerical features
tokenizer = Tokenizer(inputCol="title", outputCol="words")
remover = StopWordsRemover(inputCol="words", outputCol="filtered_words")
vectorizer = CountVectorizer(inputCol="filtered_words", outputCol="features")

# Apply K-means clustering
kmeans = KMeans(featuresCol="features", predictionCol="cluster", k=3)

# Create a pipeline
pipeline = Pipeline(stages=[tokenizer, remover, vectorizer, kmeans])

# Train the clustering model
model = pipeline.fit(df_2021_01)

# Make predictions
predictions = model.transform(df_2021_01)

# Show the clustering results
predictions.select("title", "cluster").show()

# %%
predictions.select("title", "cluster").show(n=100)

# %%
import pyspark
from pyspark import SparkContext, SparkConf
from pyspark.sql import SparkSession, SQLContext, functions as F
from pyspark.sql.functions import *
from pyspark.ml.stat import Correlation
from pyspark.ml.feature import VectorAssembler, StopWordsRemover, HashingTF, IDF
from pyspark.ml import Pipeline
import findspark
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import string
import time

findspark.init()

# # Create a SparkSession
# spark = SparkSession.builder \
#     .appName("Thesis") \
#     .getOrCreate()

# Configure Spark properties
conf = SparkConf()
conf.set("spark.executor.cores", "8")  # Number of CPU cores per executor
conf.set("spark.executor.memory", "8g")  # Memory allocated to each executor

# Create SparkSession with the configured properties
spark = SparkSession.builder \
    .appName("Thesis") \
    .config(conf=conf) \
    .getOrCreate()

df_2021_01 = spark.read.csv("Data/Reddit_2021_2022/outputRS_2021-01.csv", header=True, inferSchema=True)
df_2021_02 = spark.read.csv("Data/Reddit_2021_2022/outputRS_2021-02.csv", header=True, inferSchema=True)
merged_df_2021_01_02 = df_2021_01.union(df_2021_02)

# %%
# Start timing
start_time = time.time()

df_2021_01.groupBy("subreddit").count().orderBy(col("count").desc()).show()

# Calculate the time difference
load_time = time.time() - start_time
print("Time difference in seconds: {:.2f}".format(load_time))

# %%
# Start timing
start_time = time.time()

merged_df_2021_01_02.groupBy("subreddit").count().orderBy(col("count").desc()).show()

# Calculate the time difference
load_time = time.time() - start_time
print("Time difference in seconds: {:.2f}".format(load_time))

# %%
# Stop SparkSession
spark.stop()
